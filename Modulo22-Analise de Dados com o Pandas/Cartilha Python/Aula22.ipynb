# %% [markdown]
# -----------------------------------------Pandas e csv--------------------------------------------------------------------------------------------------

# %%
import pandas as pd

vendas_df=pd.read_csv('Contoso - Cadastro Produtos.csv')

print(vendas_df)
# Out:
#                                                                 Nome da Marca;Tipo;Custo Unitario;Preco Unitario;ID Produto;Categoria
# Contoso;Econômico;10        69;20                                                 96;873;Acessório para Computador
# Contoso;Econômico;6         63;13;879;Acessório para Computador                                                NaN
#                             63;13;880;Acessório para Computador                                                NaN
#                             63;13;881;Acessório para Computador                                                NaN
#                             63;13;882;Acessório para Computador                                                NaN
# ...                                                                                                            ...
# Southridge Video;Regular;82 77;179                                                               99;1602;Filme DVD
# ...

# %%
vendas_df
# Out:
#                                                                 Nome da Marca;Tipo;Custo Unitario;Preco Unitario;ID Produto;Categoria
# Contoso;Econômico;10        69;20                                                 96;873;Acessório para Computador
# Contoso;Econômico;6         63;13;879;Acessório para Computador                                                NaN
#                             63;13;880;Acessório para Computador                                                NaN
#                             63;13;881;Acessório para Computador                                                NaN
#                             63;13;882;Acessório para Computador                                                NaN
# ...                                                                                                            ...
# Southridge Video;Regular;82 77;179                                                               99;1602;Filme DVD
# ...

# %%
vendas_df=pd.read_csv('Contoso - Vendas - 2017.csv')

vendas_df
# Out:
#        Numero da Venda;Data da Venda;Data do Envio;ID Canal;ID Loja;ID Produto;ID Promocao;ID Cliente;Quantidade Vendida;Quantidade Devolvida
# 0             1;01/01/2017;02/01/2017;1;86;981;2;6825;9;1
# 1          2;01/01/2017;06/01/2017;5;308;1586;2;18469;9;1
# 2         3;01/01/2017;01/01/2017;0;294;1444;5;19730;13;1
# 3          4;01/01/2017;01/01/2017;0;251;1468;5;29326;6;1
# 4           5;01/01/2017;07/01/2017;6;94;1106;2;22617;4;1
# ...                                                   ...
# 980637  980638;31/12/2017;31/12/2017;0;194;2490;4;1035...
# 980638  980639;31/12/2017;06/01/2018;6;32;2488;4;31750...
# 980639  980640;31/12/2017;03/01/2018;3;210;2511;10;120...
# 980640  980641;31/12/2017;31/12/2017;0;53;436;4;25550;...
# 980641  980642;31/12/2017;31/12/2017;0;309;2510;10;287...
#
# [980642 rows x 1 columns]

# %%
vendas_df=pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')

vendas_df
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# -----------------------------------------Dataframe do Pandas--------------------------------------------------------------------------------------------------

# %%
vendas_df=pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')

vendas_df['ID Cliente']
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
vendas_df=pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')

vendas_df[:3]
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1

# %%
vendas_df=pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')

vendas_df[['Numero da Venda','Data da Venda', 'ID Produto']]
# Out:
#         Numero da Venda Data da Venda  ID Produto
# 0                     1    01/01/2017         981
# 1                     2    01/01/2017        1586
# 2                     3    01/01/2017        1444
# 3                     4    01/01/2017        1468
# 4                     5    01/01/2017        1106
# ...                 ...           ...         ...
# 980637           980638    31/12/2017        2490
# 980638           980639    31/12/2017        2488
# 980639           980640    31/12/2017        2511
# 980640           980641    31/12/2017         436
# 980641           980642    31/12/2017        2510
#
# [980642 rows x 3 columns]

# %%
vendas_df=pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')

vendas_df['ID Produto'][0]
# Out:
# 981

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %%
lista_clientes=vendas_df['ID Cliente']

lista_clientes
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
produtos_quantidade=vendas_df[['ID Produto','Quantidade Vendida','Quantidade Devolvida']]

produtos_quantidade
# Out:
#         ID Produto  Quantidade Vendida  Quantidade Devolvida
# 0              981                   9                     1
# 1             1586                   9                     1
# 2             1444                  13                     1
# 3             1468                   6                     1
# 4             1106                   4                     1
# ...            ...                 ...                   ...
# 980637        2490                 120                     0
# 980638        2488                 120                     0
# 980639        2511                  80                     0
# 980640         436                  39                     0
# 980641        2510                  80                     0
#
# [980642 rows x 3 columns]

# %% [markdown]
# -----------------------------------------Tratamento de Dados e Multiplas Bases--------------------------------------------------------------------------------------------------

# %%
import pandas as pd

#às vezes precisaremos mudar o encoding. Possiveis valores para testar:
#encoding='latin1',enconding='ISO-8859-1',encoding='utf-8' ou então encoding='cp1252'

vendas_df=pd.read_csv(r'Contoso - Vendas - 2017.csv', sep=';',encoding='cp1252')
produtos_df=pd.read_csv(r'Contoso - Cadastro Produtos.csv',sep=';',encoding='cp1252')
lojas_df=pd.read_csv(r'Contoso - Lojas.csv', sep=';',encoding='cp1252')
clientes_df=pd.read_csv(r'Contoso - Clientes.csv',sep=';',encoding='cp1252')

#usaremos o display para ver todos os dataframes

display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#axis=1 retira colunas
#axis=0 retira linhas

clientes_df=clientes_df.drop(['Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'], axis=1)
display(clientes_df)
# Out:
#        ÿID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0                1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1                2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2                3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3                4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4                5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...            ...           ...           ...                            ...
# 39499        39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500        39501        Alicia          Raje   alicia12@adventure-works.com
# 39501        39502        Connie           Rai    connie4@adventure-works.com
# 39502        39503         Shawn          Raji    shawn23@adventure-works.com
# 39503        39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
#renomear COLUNAS

lojas_df=lojas_df.rename(columns={'ÿID Loja':'ID Loja'})
clientes_df=clientes_df.rename(columns={'ÿID Cliente':'ID Cliente'})
produtos_df=produtos_df.rename(columns={'ÿNome do Produto':'Nome do Produto'})
display(lojas_df)
# Out:
#      ID Loja                         Nome da Loja  Quantidade Colaboradores  \
# 0          1           Loja Contoso Seattle No.1                       17.0
# 1          2           Loja Contoso Seattle No.2                       25.0
# 2          3              Loja Contoso Kennewick                       26.0
# 3          4               Loja Contoso Bellevue                       19.0
# 4          5                Loja Contoso Redmond                       33.0
# ..       ...                                  ...                       ...
# 301      306          Loja Contoso Europe Online                        7.0
# 302      307            Loja Contoso Asia Online                        8.0
# 303      308  Loja Contoso North America Reseller                      15.0
# 304      309         Loja Contoso Europe Reseller                      12.0
# 305      310           Loja Contoso Asia Reseller                      17.0
#
#                País
# 0    Estados Unidos
# ...

# %%
clientes_df=clientes_df[['ID Cliente','E-mail']]
produtos_df=produtos_df[['ID Produto','Nome do Produto']]
lojas_df=lojas_df[['ID Loja','Nome da Loja']]
display(produtos_df)
# Out:
#       ID Produto                                  Nome do Produto
# 0            873            Contoso Wireless Laser Mouse E50 Grey
# 1            879    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2            880   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3            881   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4            882  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...          ...                                              ...
# 1685        1602        SV DVD 12-Inch Player Portable M400 Black
# 1686        1606        SV DVD 9-Inch Player Portable M300 Silver
# 1687        1607       SV DVD 12-Inch Player Portable M400 Silver
# 1688        1611         SV DVD 9-Inch Player Portable M300 White
# 1689        1612        SV DVD 12-Inch Player Portable M400 White
#
# [1690 rows x 2 columns]

# %%
#Juntando os dataframes

vendas_df=vendas_df.merge(produtos_df, on='ID Produto')
vendas_df=vendas_df.merge(lojas_df, on='ID Loja')
vendas_df=vendas_df.merge(clientes_df, on='ID Cliente')

display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ----------------------------------------Análises e Visualização de Dados no Pandas (Parte1)------------------------------------------------------

# %%
frequencia_clientes=vendas_df['E-mail'].value_counts()
display(frequencia_clientes)
frequencia_clientes.plot()
# Out:
# E-mail
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# gilbert9@adventure-works.com     68
# destiny66@adventure-works.com    68
#                                  ..
# mblemen9o@ebay.com                1
# rebecca15@adventure-works.com     1
# kevin10@adventure-works.com       1
# siliffe8l@spotify.com             1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64
# <Axes: xlabel='E-mail'>

# %%
frequencia_clientes=vendas_df['E-mail'].value_counts()
display(frequencia_clientes)
frequencia_clientes[:5].plot(figsize=(15,5))
# Out:
# E-mail
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# gilbert9@adventure-works.com     68
# destiny66@adventure-works.com    68
#                                  ..
# mblemen9o@ebay.com                1
# rebecca15@adventure-works.com     1
# kevin10@adventure-works.com       1
# siliffe8l@spotify.com             1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64
# <Axes: xlabel='E-mail'>

# %% [markdown]
# ----------------------------------------Análises e Visualização de Dados no Pandas (Parte2)------------------------------------------------------

# %%
vendas_lojas=vendas_df.groupby('Nome da Loja').sum()
display(vendas_lojas)
# Out:
#                           Numero da Venda  \
# Nome da Loja
# Loja Contoso Albany            1202431493
# Loja Contoso Alexandria        1180450098
# Loja Contoso Amsterdam         1463641203
# Loja Contoso Anchorage         1214566953
# Loja Contoso Annapolis         1196644689
# ...                                   ...
# Loja Contoso Yokohama          1277269788
# Loja Contoso York              1447746885
# Loja Contoso koln No.1         1473231489
# Loja Contoso koln No.2         1495673435
# Loja Contoso obamberg          1443837839
#
#                                                               Data da Venda  \
# Nome da Loja
# Loja Contoso Albany       01/01/201701/01/201701/01/201701/01/201701/01/...
# Loja Contoso Alexandria   01/01/201701/01/201701/01/201701/01/201701/01/...
# Loja Contoso Amsterdam    01/01/201701/01/201701/01/201701/01/201701/01/...
# Loja Contoso Anchorage    01/01/201701/01/201701/01/201701/01/201701/01/...
# ...

# %%
vendas_lojas=vendas_df.groupby('Nome da Loja').sum()
vendas_lojas=vendas_lojas[['Quantidade Vendida']]
display(vendas_lojas)
# Out:
#                           Quantidade Vendida
# Nome da Loja
# Loja Contoso Albany                    26353
# Loja Contoso Alexandria                26247
# Loja Contoso Amsterdam                 28294
# Loja Contoso Anchorage                 27451
# Loja Contoso Annapolis                 26065
# ...                                      ...
# Loja Contoso Yokohama                  28023
# Loja Contoso York                      27164
# Loja Contoso koln No.1                 29046
# Loja Contoso koln No.2                 29650
# Loja Contoso obamberg                  29336
#
# [306 rows x 1 columns]

# %%
vendas_lojas=vendas_lojas.sort_values('Quantidade Vendida',ascending=False)
display(vendas_lojas)
# Out:
#                                      Quantidade Vendida
# Nome da Loja
# Loja Contoso Catalog                            1029117
# Loja Contoso North America Online                701961
# Loja Contoso Europe Online                       616845
# Loja Contoso Asia Online                         578458
# Loja Contoso North America Reseller              520176
# ...                                                 ...
# Loja Contoso Berlin                                 379
# Loja Contoso Paterson                               371
# Loja Contoso Marseille                              370
# Loja Contoso Racine No.2                            253
# Loja Contoso Venezia                                234
#
# [306 rows x 1 columns]

# %%
vendas_lojas=vendas_lojas.sort_values('Quantidade Vendida',ascending=False)
vendas_lojas[:5].plot(figsize=(15,5), kind='bar')
# Out:
# <Axes: xlabel='Nome da Loja'>

# %%
maior_valor=vendas_lojas['Quantidade Vendida'].max()
melhor_loja=vendas_lojas['Quantidade Vendida'].idxmax()
print(melhor_loja,maior_valor)

menor_valor=vendas_lojas['Quantidade Vendida'].min()
pior_loja=vendas_lojas['Quantidade Vendida'].idxmin()
print(pior_loja,menor_valor)
# Out:
# Loja Contoso Catalog  1029117
# Loja Contoso Venezia  234

# %% [markdown]
# ----------------------------------------Filtrando um dataframe------------------------------------------------------

# %%
qtde_vendida = vendas_df['Quantidade Vendida'].sum()
qtde_devoldida=vendas_df['Quantidade Devolvida'].sum()

print('{:.2%}'.format(qtde_devoldida/qtde_vendida))
# Out:
# 1.17%

# %%
vendas_lojacontosoeuropeonline=vendas_df[vendas_df['ID Loja']==306]
display(vendas_lojacontosoeuropeonline)
qtde_vendida = vendas_lojacontosoeuropeonline['Quantidade Vendida'].sum()
qtde_devoldida=vendas_lojacontosoeuropeonline['Quantidade Devolvida'].sum()
print('{:.2%}'.format(qtde_devoldida/qtde_vendida))
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
loja306=vendas_df['ID Loja']==306
display(loja306)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 980637    False
# 980638    False
# 980639    False
# 980640    False
# 980641    False
# Name: ID Loja, Length: 980642, dtype: bool

# %%
loja306=vendas_df['ID Loja']==306
vendas_lojacontosoeuropeonline=vendas_df[loja306]
display(vendas_lojacontosoeuropeonline)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
df_loja306semdev=vendas_df[(vendas_df['ID Loja']==306) & (vendas_df['Quantidade Devolvida']==0)]
display(df_loja306semdev)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...
